# %% [markdown]
# # LSTM on Plant 2

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
import datetime

# Load and preprocess generation data
gen_data = pd.read_csv('Datasets\Processed Datasets\Plant2_filtered.csv')  # Adjust path
gen_data['DATE_TIME'] = pd.to_datetime(gen_data['DATE_TIME'], format='mixed', dayfirst=True)

# Aggregate AC_POWER across inverters
gen_agg = gen_data.groupby('DATE_TIME')['AC_POWER'].sum().reset_index()
gen_agg.columns = ['DATE_TIME', 'total_AC_POWER']

# Load and preprocess weather data
weather_data = pd.read_csv('Datasets\Processed Datasets\Plant2_Weather_filtered.csv')  # Adjust path
weather_data['DATE_TIME'] = pd.to_datetime(weather_data['DATE_TIME'], format='mixed')

# Merge datasets
data = pd.merge(gen_agg, weather_data[['DATE_TIME', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']],
                on='DATE_TIME', how='inner')

# Add time features
data['hour'] = data['DATE_TIME'].dt.hour
data['minute'] = data['DATE_TIME'].dt.minute
data['hour_sin'] = np.sin(2 * np.pi * data['hour'] / 24)
data['hour_cos'] = np.cos(2 * np.pi * data['hour'] / 24)

# Define features and target
features = ['total_AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'hour_sin', 'hour_cos']
target = 'total_AC_POWER'

# Normalize features
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data[features])
scaled_df = pd.DataFrame(scaled_data, columns=features, index=data.index)
scaled_df['DATE_TIME'] = data['DATE_TIME']

# Define horizons
horizons = [4, 20, 96, 288]  # 1h, 5h, 1d, 3d (in 15-min intervals)
horizons_labels = ['1 hour', '5 hours', '1 day', '3 days']
max_horizon = max(horizons)

# Create sequences for each horizon
def create_sequences_single_horizon(df, seq_length, horizon):
    X, y = [], []
    for i in range(len(df) - seq_length - horizon):
        X.append(df[features].iloc[i:i+seq_length].values)
        # Target is the average AC_POWER over the horizon
        y_avg = df[target].iloc[i+seq_length:i+seq_length+horizon].mean()
        y.append(y_avg)
    return np.array(X), np.array(y)

seq_length = 4  # 1 hour (4 * 15 min)

# Train separate models for each horizon
models = {}
histories = {}
predictions = {}
test_actuals = {}

for horizon_idx, horizon in enumerate(horizons):
    print(f"\nTraining model for {horizons_labels[horizon_idx]} horizon...")

    # Create sequences for current horizon
    X, y = create_sequences_single_horizon(scaled_df, seq_length, horizon)

    # Split data chronologically
    train_size = int(0.8 * len(X))
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Build LSTM model for this horizon
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(seq_length, len(features)), return_sequences=False))
    model.add(Dense(1))  # Single output for this horizon
    model.compile(optimizer='adam', loss='mse')

    # Train model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1, verbose=1)

    # Store model and history
    models[horizons_labels[horizon_idx]] = model
    histories[horizons_labels[horizon_idx]] = history

    # Predict
    y_pred = model.predict(X_test)

    # Inverse scale predictions (target is first column in scaler)
    min_ac = scaler.data_min_[0]
    scale_ac = scaler.scale_[0]
    y_test_rescaled = y_test / scale_ac + min_ac
    y_pred_rescaled = y_pred.flatten() / scale_ac + min_ac

    # Store predictions and actuals
    predictions[horizons_labels[horizon_idx]] = y_pred_rescaled
    test_actuals[horizons_labels[horizon_idx]] = y_test_rescaled

    # Evaluate
    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    rmse = np.sqrt(mean_squared_error(y_test_rescaled, y_pred_rescaled))
    print(f'{horizons_labels[horizon_idx]} - MAE: {mae:.2f}, RMSE: {rmse:.2f}')

    # Save model
    model.save(f'plant1_lstm_model_{horizons_labels[horizon_idx].replace(" ", "_")}.h5')

# Baseline: Persistence model for each horizon
print("\nBaseline Persistence Model Results:")
for horizon_idx, horizon in enumerate(horizons):
    X, y = create_sequences_single_horizon(scaled_df, seq_length, horizon)
    train_size = int(0.8 * len(X))
    y_test = y[train_size:]

    # Persistence: use last value of sequence as prediction
    persistence_pred = X[train_size:, -1, 0]  # Last AC_POWER value from each sequence

    # Inverse scale
    min_ac = scaler.data_min_[0]
    scale_ac = scaler.scale_[0]
    y_test_rescaled = y_test / scale_ac + min_ac
    persistence_pred_rescaled = persistence_pred / scale_ac + min_ac

    persistence_mae = mean_absolute_error(y_test_rescaled, persistence_pred_rescaled)
    persistence_rmse = np.sqrt(mean_squared_error(y_test_rescaled, persistence_pred_rescaled))
    print(f'{horizons_labels[horizon_idx]} - Persistence MAE: {persistence_mae:.2f}, RMSE: {persistence_rmse:.2f}')

# Plot results for all horizons
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

for i, horizon_label in enumerate(horizons_labels):
    axes[i].plot(test_actuals[horizon_label][:100], label='Actual', alpha=0.7)
    axes[i].plot(predictions[horizon_label][:100], label='Predicted', alpha=0.7)
    axes[i].set_title(f'{horizon_label} Average Prediction')
    axes[i].set_xlabel('Time Step')
    axes[i].set_ylabel('AC_POWER (kW)')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Inference: Predict future averages for all horizons
print("\nEnter current data for prediction:")
current_ac = float(input("Enter current total_AC_POWER (0 to 10000): "))
current_amb_temp = float(input("Enter current AMBIENT_TEMPERATURE (0 to 50): "))
current_mod_temp = float(input("Enter current MODULE_TEMPERATURE (0 to 70): "))
current_irr = float(input("Enter current IRRADIATION (0 to 1.5): "))

# Create sequence by repeating current input
current_time = datetime.datetime.now()
sequence_times = [current_time - datetime.timedelta(minutes=15*(seq_length - 1 - i)) for i in range(seq_length)]
sequence_df = pd.DataFrame({
    'DATE_TIME': sequence_times,
    'total_AC_POWER': [current_ac] * seq_length,
    'AMBIENT_TEMPERATURE': [current_amb_temp] * seq_length,
    'MODULE_TEMPERATURE': [current_mod_temp] * seq_length,
    'IRRADIATION': [current_irr] * seq_length,
})
sequence_df['hour'] = sequence_df['DATE_TIME'].dt.hour
sequence_df['minute'] = sequence_df['DATE_TIME'].dt.minute
sequence_df['hour_sin'] = np.sin(2 * np.pi * sequence_df['hour'] / 24)
sequence_df['hour_cos'] = np.cos(2 * np.pi * sequence_df['hour'] / 24)
sequence_features = sequence_df[features]
sequence_scaled = scaler.transform(sequence_features)

# Predict for all horizons using respective models
min_ac = scaler.data_min_[0]
scale_ac = scaler.scale_[0]

print("\nPredictions for all horizons:")
for horizon_label in horizons_labels:
    prediction_scaled = models[horizon_label].predict(sequence_scaled[np.newaxis, :, :])[0, 0]
    prediction_rescaled = prediction_scaled / scale_ac + min_ac
    print(f"Predicted average AC_POWER for next {horizon_label}: {prediction_rescaled:.2f} kW")
# Out:
# Training model for 1 hour horizon...
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.1466 - val_loss: 0.0201
# Epoch 2/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - val_loss: 0.0102
# Epoch 3/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114 - val_loss: 0.0097
# Epoch 4/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 5/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 6/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - val_loss: 0.0081
# Epoch 7/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - val_loss: 0.0078
# Epoch 8/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 9/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 10/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 11/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 12/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - val_loss: 0.0080
# Epoch 13/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0080
# Epoch 14/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 15/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 16/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 17/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 18/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0073
# Epoch 19/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - val_loss: 0.0083
# Epoch 20/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - val_loss: 0.0075
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1 hour - MAE: 1656.74, RMSE: 2127.74
#
# Training model for 5 hours horizon...
# Epoch 1/20
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1034 - val_loss: 0.0150
# Epoch 2/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0130 - val_loss: 0.0068
# Epoch 3/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0054
# Epoch 4/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 5/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 6/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 7/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 8/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - val_loss: 0.0050
# Epoch 9/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 10/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - val_loss: 0.0050
# Epoch 11/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 12/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 13/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 14/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 15/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 16/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 17/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 18/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 19/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 20/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0053
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 5 hours - MAE: 1323.22, RMSE: 1629.78
#
# Training model for 1 day horizon...
# Epoch 1/20
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0724 - val_loss: 0.0026
# Epoch 2/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 3/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 4/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 5/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 6/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 7/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 8/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 9/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 10/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 11/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 12/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 13/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 14/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 15/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 16/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 17/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 18/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 19/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 20/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0022
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1 day - MAE: 1034.94, RMSE: 1284.09
#
# Training model for 3 days horizon...
# Epoch 1/20
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0648 - val_loss: 0.0070
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2639e-04 - val_loss: 0.0015
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8457e-04 - val_loss: 0.0013
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8910e-04 - val_loss: 0.0012
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8508e-04 - val_loss: 9.3354e-04
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5562e-04 - val_loss: 7.9289e-04
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2134e-04 - val_loss: 6.4450e-04
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4501e-04 - val_loss: 5.5612e-04
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8833e-04 - val_loss: 5.0548e-04
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7683e-04 - val_loss: 4.4558e-04
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2848e-04 - val_loss: 3.9571e-04
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2464e-04 - val_loss: 3.5359e-04
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9237e-04 - val_loss: 3.3407e-04
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8097e-04 - val_loss: 3.1965e-04
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7763e-04 - val_loss: 3.3326e-04
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7109e-04 - val_loss: 3.1861e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3 days - MAE: 1043.72, RMSE: 1088.69
#
# Baseline Persistence Model Results:
# 1 hour - Persistence MAE: 2498.67, RMSE: 3157.69
# 5 hours - Persistence MAE: 4509.50, RMSE: 5314.93
# 1 day - Persistence MAE: 4424.51, RMSE: 5111.68
# 3 days - Persistence MAE: 4952.70, RMSE: 5549.64
# Enter current data for prediction:
#
# Predictions for all horizons:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted average AC_POWER for next 1 hour: 5436.49 kW
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted average AC_POWER for next 5 hours: 8088.61 kW
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted average AC_POWER for next 1 day: 8099.89 kW
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted average AC_POWER for next 3 days: 9434.09 kW

# %% [markdown]
# # Improvements on Plant 2 LSTM with Fourier Approximation

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
import datetime

# Load and preprocess generation data
gen_data = pd.read_csv('Datasets\Processed Datasets\Plant2_filtered.csv')  # Adjust path
gen_data['DATE_TIME'] = pd.to_datetime(gen_data['DATE_TIME'], format='mixed', dayfirst=True)

# Aggregate AC_POWER across inverters
gen_agg = gen_data.groupby('DATE_TIME')['AC_POWER'].sum().reset_index()
gen_agg.columns = ['DATE_TIME', 'total_AC_POWER']

# Load and preprocess weather data
weather_data = pd.read_csv('Datasets\Processed Datasets\Plant2_Weather_filtered.csv')  # Adjust path
weather_data['DATE_TIME'] = pd.to_datetime(weather_data['DATE_TIME'], format='mixed')

# Merge datasets
data = pd.merge(gen_agg, weather_data[['DATE_TIME', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']],
                on='DATE_TIME', how='inner')

# Add time features
data['hour'] = data['DATE_TIME'].dt.hour
data['minute'] = data['DATE_TIME'].dt.minute
data['hour_sin'] = np.sin(2 * np.pi * data['hour'] / 24)
data['hour_cos'] = np.cos(2 * np.pi * data['hour'] / 24)

# Define features and target
features = ['total_AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'hour_sin', 'hour_cos']
target = 'total_AC_POWER'

# Normalize features
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data[features])
scaled_df = pd.DataFrame(scaled_data, columns=features, index=data.index)
scaled_df['DATE_TIME'] = data['DATE_TIME']

# Define horizons
horizons = [4, 20, 96, 288]  # 1h, 5h, 1d, 3d (in 15-min intervals)
horizons_labels = ['1 hour', '5 hours', '1 day', '3 days']
max_horizon = max(horizons)

# Create sequences for each horizon
def create_sequences_single_horizon(df, seq_length, horizon):
    X, y = [], []
    for i in range(len(df) - seq_length - horizon):
        X.append(df[features].iloc[i:i+seq_length].values)
        # Target is the average AC_POWER over the horizon
        y_avg = df[target].iloc[i+seq_length:i+seq_length+horizon].mean()
        y.append(y_avg)
    return np.array(X), np.array(y)

seq_length = 4  # 1 hour (4 * 15 min)

# Train separate models for each horizon
models = {}
histories = {}
predictions = {}
test_actuals = {}

for horizon_idx, horizon in enumerate(horizons):
    print(f"\nTraining model for {horizons_labels[horizon_idx]} horizon...")

    # Create sequences for current horizon
    X, y = create_sequences_single_horizon(scaled_df, seq_length, horizon)

    # Split data chronologically
    train_size = int(0.8 * len(X))
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Build LSTM model for this horizon
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(seq_length, len(features)), return_sequences=False))
    model.add(Dense(1))  # Single output for this horizon
    model.compile(optimizer='adam', loss='mse')

    # Train model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1, verbose=1)

    # Store model and history
    models[horizons_labels[horizon_idx]] = model
    histories[horizons_labels[horizon_idx]] = history

    # Predict
    y_pred = model.predict(X_test)

    # Inverse scale predictions (target is first column in scaler)
    min_ac = scaler.data_min_[0]
    scale_ac = scaler.scale_[0]
    y_test_rescaled = y_test / scale_ac + min_ac
    y_pred_rescaled = y_pred.flatten() / scale_ac + min_ac

    # Store predictions and actuals
    predictions[horizons_labels[horizon_idx]] = y_pred_rescaled
    test_actuals[horizons_labels[horizon_idx]] = y_test_rescaled

    # Evaluate
    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    rmse = np.sqrt(mean_squared_error(y_test_rescaled, y_pred_rescaled))
    print(f'{horizons_labels[horizon_idx]} - MAE: {mae:.2f}, RMSE: {rmse:.2f}')

    # Save model
    model.save(f'plant1_lstm_model_{horizons_labels[horizon_idx].replace(" ", "_")}.h5')

# Baseline: Persistence model for each horizon
print("\nBaseline Persistence Model Results:")
for horizon_idx, horizon in enumerate(horizons):
    X, y = create_sequences_single_horizon(scaled_df, seq_length, horizon)
    train_size = int(0.8 * len(X))
    y_test = y[train_size:]

    # Persistence: use last value of sequence as prediction
    persistence_pred = X[train_size:, -1, 0]  # Last AC_POWER value from each sequence

    # Inverse scale
    min_ac = scaler.data_min_[0]
    scale_ac = scaler.scale_[0]
    y_test_rescaled = y_test / scale_ac + min_ac
    persistence_pred_rescaled = persistence_pred / scale_ac + min_ac

    persistence_mae = mean_absolute_error(y_test_rescaled, persistence_pred_rescaled)
    persistence_rmse = np.sqrt(mean_squared_error(y_test_rescaled, persistence_pred_rescaled))
    print(f'{horizons_labels[horizon_idx]} - Persistence MAE: {persistence_mae:.2f}, RMSE: {persistence_rmse:.2f}')

# Plot results for all horizons
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

for i, horizon_label in enumerate(horizons_labels):
    axes[i].plot(test_actuals[horizon_label][:100], label='Actual', alpha=0.7)
    axes[i].plot(predictions[horizon_label][:100], label='Predicted', alpha=0.7)
    axes[i].set_title(f'{horizon_label} Average Prediction')
    axes[i].set_xlabel('Time Step')
    axes[i].set_ylabel('AC_POWER (kW)')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Inference: Predict future averages for all horizons
print("\nEnter current data for prediction:")
current_ac = float(input("Enter current total_AC_POWER (0 to 10000): "))
current_amb_temp = float(input("Enter current AMBIENT_TEMPERATURE (0 to 50): "))
current_mod_temp = float(input("Enter current MODULE_TEMPERATURE (0 to 70): "))
current_irr = float(input("Enter current IRRADIATION (0 to 1.5): "))

# Create sequence by repeating current input
current_time = datetime.datetime.now()
sequence_times = [current_time - datetime.timedelta(minutes=15*(seq_length - 1 - i)) for i in range(seq_length)]
sequence_df = pd.DataFrame({
    'DATE_TIME': sequence_times,
    'total_AC_POWER': [current_ac] * seq_length,
    'AMBIENT_TEMPERATURE': [current_amb_temp] * seq_length,
    'MODULE_TEMPERATURE': [current_mod_temp] * seq_length,
    'IRRADIATION': [current_irr] * seq_length,
})
sequence_df['hour'] = sequence_df['DATE_TIME'].dt.hour
sequence_df['minute'] = sequence_df['DATE_TIME'].dt.minute
sequence_df['hour_sin'] = np.sin(2 * np.pi * sequence_df['hour'] / 24)
sequence_df['hour_cos'] = np.cos(2 * np.pi * sequence_df['hour'] / 24)
sequence_features = sequence_df[features]
sequence_scaled = scaler.transform(sequence_features)

# Predict for all horizons using respective models
min_ac = scaler.data_min_[0]
scale_ac = scaler.scale_[0]

print("\nPredictions for all horizons:")
for horizon_label in horizons_labels:
    prediction_scaled = models[horizon_label].predict(sequence_scaled[np.newaxis, :, :])[0, 0]
    prediction_rescaled = prediction_scaled / scale_ac + min_ac
    print(f"Predicted average AC_POWER for next {horizon_label}: {prediction_rescaled:.2f} kW")
# Out:
# Training model for 1 hour horizon...
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1368 - val_loss: 0.0295
# Epoch 2/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0092
# Epoch 3/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - val_loss: 0.0094
# Epoch 4/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 5/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - val_loss: 0.0085
# Epoch 6/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 7/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 8/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 9/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 10/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0065
# Epoch 11/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 12/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 13/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 14/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 15/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 16/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 17/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 18/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0067
# Epoch 19/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.0064
# Epoch 20/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - val_loss: 0.0064
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1 hour - MAE: 1562.99, RMSE: 2029.76
#
# Training model for 5 hours horizon...
# Epoch 1/20
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1251 - val_loss: 0.0091
# Epoch 2/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - val_loss: 0.0065
# Epoch 3/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0057
# Epoch 4/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 5/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 6/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 7/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 8/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 9/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 10/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 11/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - val_loss: 0.0051
# Epoch 12/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 13/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 14/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 15/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 16/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 17/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 18/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 19/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 20/20
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - val_loss: 0.0051
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 5 hours - MAE: 1351.24, RMSE: 1687.22
#
# Training model for 1 day horizon...
# Epoch 1/20
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0363 - val_loss: 0.0027
# Epoch 2/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 3/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 4/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 5/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 6/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 7/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 8/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 9/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 10/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 11/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 12/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 13/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 14/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 15/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 16/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 17/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 18/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 19/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 20/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0024
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1 day - MAE: 1158.42, RMSE: 1426.71
#
# Training model for 3 days horizon...
# Epoch 1/20
# c:\Users\jetha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0508 - val_loss: 0.0047
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1322e-04 - val_loss: 0.0020
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1689e-04 - val_loss: 0.0011
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3238e-04 - val_loss: 8.1278e-04
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3921e-04 - val_loss: 6.1914e-04
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8401e-04 - val_loss: 5.4458e-04
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7801e-04 - val_loss: 4.2412e-04
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5838e-04 - val_loss: 3.8041e-04
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3634e-04 - val_loss: 3.5347e-04
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1998e-04 - val_loss: 3.0389e-04
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8834e-04 - val_loss: 3.3253e-04
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1049e-04 - val_loss: 2.8537e-04
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8479e-04 - val_loss: 2.6405e-04
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9539e-04 - val_loss: 2.5514e-04
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9301e-04 - val_loss: 2.4798e-04
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6870e-04 - val_loss: 2.4692e-04
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7069e-04 - val_loss: 2.4703e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3 days - MAE: 949.60, RMSE: 1001.83
#
# Baseline Persistence Model Results:
# 1 hour - Persistence MAE: 2498.67, RMSE: 3157.69
# 5 hours - Persistence MAE: 4509.50, RMSE: 5314.93
# 1 day - Persistence MAE: 4424.51, RMSE: 5111.68
# 3 days - Persistence MAE: 4952.70, RMSE: 5549.64
# Enter current data for prediction:
#
# Predictions for all horizons:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted average AC_POWER for next 1 hour: 4773.22 kW
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted average AC_POWER for next 5 hours: 8367.56 kW
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted average AC_POWER for next 1 day: 8165.01 kW
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted average AC_POWER for next 3 days: 9088.85 kW
